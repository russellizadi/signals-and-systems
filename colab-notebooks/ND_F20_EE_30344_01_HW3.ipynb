# %% [markdown]
# <a href="https://colab.research.google.com/github/russellizadi/signals-and-systems/blob/master/colab-notebooks/ND_F20_EE_30344_01_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.io
from scipy import signal
from IPython.display import Audio

# %%
# upload the lineup.mat through the "files" section on the left

# load 
data = scipy.io.loadmat('lineup.mat')
y = data['y'][:, 0]
fs = 8192
print(f"duration = {len(y)/fs} (s)")

# plot
n = np.arange(0, len(y))
plt.plot(n, y)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("y")
plt.show()

# play
Audio(y,rate=fs,autoplay=True)
# Out:
# duration = 0.8544921875 (s)
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# a
def dirac(n):
    return np.where(n == 0, 1.0, 0.0)

a = .5
N = 1000

ne = np.arange(0, 1001)
he = dirac(ne) + a*dirac(ne-N)

plt.plot(ne, he)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("he")
plt.show()

# %%
# c
ner = np.arange(4001)
d = dirac(ner)

nom = np.zeros(N+1)
nom[0], nom[-1] = 1., a
den = np.zeros(N+1)
den[0], den[-1] = 1., a

her = signal.lfilter(den, nom, d)

plt.plot(ner, her)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("her")
plt.show()

# %%
# d
z = signal.lfilter(den, nom, y)

plt.plot(n, z)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("z")
plt.show()
Audio(z,rate=fs,autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# e
hoa = np.convolve(he, her)
noa = np.arange(0, len(hoa))
plt.plot(noa, hoa)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("hoa")
plt.show()
